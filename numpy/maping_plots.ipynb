# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0,10,10)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.xlabel("time")
plt.ylabel("some function of time")
plt.title("my cool chart")
# Out:
# Text(0.5, 1.0, 'my cool chart')

# %%
x = np.linspace(0,10,100)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.xlabel("time")
plt.ylabel("some function of time")
plt.title("my cool chart")
# Out:
# Text(0.5, 1.0, 'my cool chart')

# %%
import pandas as pd

# %%
a = pd.read_csv('data_1d.csv', header=None).as_matrix()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
x = a[:,0]
y = a[:,1]

# %%
plt.scatter(x,y)

# %%
x_line = np.linspace(0,100,100)

# %%
y_line = 2*x_line+1

# %%
plt.scatter(x,y)
plt.plot(x_line, y_line)

# %%
plt.hist(x)
# Out:
# (array([10.,  9.,  5., 13., 10., 10.,  8., 16., 10.,  9.]),
#  array([ 3.21124861, 12.88597188, 22.56069515, 32.23541842, 41.91014169,
#         51.58486496, 61.25958823, 70.9343115 , 80.60903477, 90.28375804,
#         99.95848131]),
#  <a list of 10 Patch objects>)

# %%
r = np.random.random(10000)

# %%
plt.hist(r)
# Out:
# (array([ 980.,  995.,  988., 1054.,  958., 1009., 1047.,  967., 1008.,
#          994.]),
#  array([3.59431709e-05, 1.00025717e-01, 2.00015491e-01, 3.00005266e-01,
#         3.99995040e-01, 4.99984814e-01, 5.99974588e-01, 6.99964362e-01,
#         7.99954136e-01, 8.99943910e-01, 9.99933684e-01]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(r, bins=20)
# Out:
# (array([488., 492., 481., 514., 497., 491., 537., 517., 482., 476., 508.,
#         501., 526., 521., 468., 499., 493., 515., 469., 525.]),
#  array([3.59431709e-05, 5.00308302e-02, 1.00025717e-01, 1.50020604e-01,
#         2.00015491e-01, 2.50010378e-01, 3.00005266e-01, 3.50000153e-01,
#         3.99995040e-01, 4.49989927e-01, 4.99984814e-01, 5.49979701e-01,
#         5.99974588e-01, 6.49969475e-01, 6.99964362e-01, 7.49959249e-01,
#         7.99954136e-01, 8.49949023e-01, 8.99943910e-01, 9.49938797e-01,
#         9.99933684e-01]),
#  <a list of 20 Patch objects>)

# %%
y_actual = 2*x+1

# %%
residuals = y - y_actual

# %%
plt.hist(residuals)
# Out:
# (array([ 6.,  7., 15., 14., 12., 18., 13.,  7.,  6.,  2.]),
#  array([-9.78834827, -7.57337797, -5.35840768, -3.14343738, -0.92846708,
#          1.28650321,  3.50147351,  5.7164438 ,  7.9314141 , 10.14638439,
#         12.36135469]),
#  <a list of 10 Patch objects>)
